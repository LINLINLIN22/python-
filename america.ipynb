# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
from sklearn import linear_model
import matplotlib.image as mpimg
lm = linear_model.LinearRegression()
America= pd.read_csv("movie_America.csv") 
features=['Log_Confirmed']
X = America[features]
y = America['log_movie']
print(X.shape,y.shape)
model = lm.fit(X,y)
print("截距:", model.intercept_, "迴歸係數:", model.coef_)
predicts = model.predict(X)
R2 = model.score(X, y)
print('R2 = %.2f' % R2)
regression_y = lm.predict(X)
plt.scatter(X,y) 
plt.xlabel('Log_Confirmed') 
plt.ylabel('log_movie') 
plt.title('American_moviedata_linerRegression')
plt.plot(X, regression_y, color="blue")
plt.plot(X, predicts, color="red", marker="o", markersize=1)
plt.savefig("american_logmovie_logconfirmed.png")
# Out:
# (74, 1) (74,)
# 截距: 7.699148188099317 迴歸係數: [-0.17186511]
# R2 = 0.08
